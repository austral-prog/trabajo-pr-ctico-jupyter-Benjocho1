# %% [markdown]
# # [EXERCISE 1]
# ## Benjamin Aberg Cobo
# ## babergcobo@mail.austra.edu.ar
# ![anthony1-exodia-sienna-sleep-ateriavia-Cover-Art.png](attachment:8e328621-f956-4587-b71b-3550811592fe.png)
# ### this is my favorite album

# %% [markdown]
# # [EXCERCISE 5]

# %% [markdown]
# # sum

# %%
a = 3 
b = 7

sum = (a + b)


print(sum)
# Out:
# 10

# %% [markdown]
# # substraction

# %%
a = 3 
b = 7


substraction = (a - b)

print(substraction)
# Out:
# -4

# %% [markdown]
# # multiplication

# %%
a = 3 
b = 7


multiplication = (a * b)


print(multiplication)
# Out:
# 21

# %% [markdown]
# # division

# %%
a = 3 
b = 7

division = (a / b)

print(division)
# Out:
# 0.42857142857142855
